# %% [markdown]
# # This notebook analyzes the glycosidic torsion x for the rg and unmod for the central 10 steps around the lesion
#
# ## First of all, import usful libraries

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import sys, getopt

from matplotlib import pyplot
from pylab import *
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_color_codes("pastel")
sns.set(style="darkgrid")
# Out:
# /Users/yuqincai/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## Read data, first 10 columns are for rg; second 10 clumns are for unmod

# %%
df=pd.read_csv("./rg10_unmod10_chi", header=None, delim_whitespace=True).reset_index()

# %%
df[:5]
# Out:
#    index         0         1         2         3        4         5         6  \
# 0      0  -59.2513  165.8372   83.5081  116.8386  35.0590  149.8438 -153.1143
# 1      1  -51.9629  -78.2528  102.2039   85.5357 -13.3698   97.6019 -131.5027
# 2      2 -115.8034  -31.7155  118.6797   86.4147 -15.5264  -34.9067  -76.6973
# 3      3  138.9181   22.3741  110.6671  101.8984   6.0773  -68.3640 -143.4175
# 4      4  -62.8545  -58.8034   85.0064   91.0527   6.1394  -79.3681 -165.7273
#
#           7         8    ...           10       11        12        13  \
# 0   86.4617  117.8808    ...    -126.2834 -82.6194   78.1411   83.5118
# 1   83.8460  107.5770    ...     -84.6551 -57.8616   87.9330   57.3907
# 2   64.0712  106.9056    ...     -76.1232 -61.4462   73.7802   58.1371
# 3  112.9166   99.0886    ...     -78.4769 -34.3623   70.0909   70.4467
# 4  105.1124  124.0989    ...     -99.5704 -93.0268  107.4481  114.8272
#
#         14        15        16        17        18        19
# 0  58.0048  179.0481  -98.3822  122.4371   98.4780  -76.8777
# 1  58.7422  -70.7860 -161.7669  108.7448  102.4572 -110.6482
# 2  94.1746   -7.5243  -49.2028  111.7993  116.6765  -80.5922
# 3  92.4743  -49.6539  -28.0702  101.9498   95.7988  -26.3158
# 4  44.3946  -36.9158  -62.1817  103.8009   82.5470 -162.1888
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Create the column names; 10 for rg, 10 for unmod

# %%
list1=["index"]
list2=["rg"+str(x) for x in range(69,79)]
list3=["unmod"+str(x) for x in range(69,79)]
names= list1+list2+list3

# %% [markdown]
# ## Assign column names, and review the dataframe

# %%
df.columns=names
print df.shape
df[:5]
#print df.drop(df.columns[[0]], axis=1, inplace=True)
# Out:
# (70000, 21)
#    index      rg69      rg70      rg71      rg72     rg73      rg74      rg75  \
# 0      0  -59.2513  165.8372   83.5081  116.8386  35.0590  149.8438 -153.1143
# 1      1  -51.9629  -78.2528  102.2039   85.5357 -13.3698   97.6019 -131.5027
# 2      2 -115.8034  -31.7155  118.6797   86.4147 -15.5264  -34.9067  -76.6973
# 3      3  138.9181   22.3741  110.6671  101.8984   6.0773  -68.3640 -143.4175
# 4      4  -62.8545  -58.8034   85.0064   91.0527   6.1394  -79.3681 -165.7273
#
#        rg76      rg77    ...      unmod69  unmod70   unmod71   unmod72  \
# 0   86.4617  117.8808    ...    -126.2834 -82.6194   78.1411   83.5118
# 1   83.8460  107.5770    ...     -84.6551 -57.8616   87.9330   57.3907
# 2   64.0712  106.9056    ...     -76.1232 -61.4462   73.7802   58.1371
# 3  112.9166   99.0886    ...     -78.4769 -34.3623   70.0909   70.4467
# 4  105.1124  124.0989    ...     -99.5704 -93.0268  107.4481  114.8272
#
#    unmod73   unmod74   unmod75   unmod76   unmod77   unmod78
# 0  58.0048  179.0481  -98.3822  122.4371   98.4780  -76.8777
# 1  58.7422  -70.7860 -161.7669  108.7448  102.4572 -110.6482
# 2  94.1746   -7.5243  -49.2028  111.7993  116.6765  -80.5922
# 3  92.4743  -49.6539  -28.0702  101.9498   95.7988  -26.3158
# 4  44.3946  -36.9158  -62.1817  103.8009   82.5470 -162.1888
#
# [5 rows x 21 columns]

# %%
df["rg78"][:5]
# Out:
# 0   -120.6037
# 1   -134.6709
# 2   -154.0165
# 3   -115.9039
# 4    -27.4217
# Name: rg78, dtype: float64

# %%
print df.columns
# Out:
# Index([u'index', u'rg69', u'rg70', u'rg71', u'rg72', u'rg73', u'rg74', u'rg75',
#        u'rg76', u'rg77', u'rg78', u'unmod69', u'unmod70', u'unmod71',
#        u'unmod72', u'unmod73', u'unmod74', u'unmod75', u'unmod76', u'unmod77',
#        u'unmod78'],
#       dtype='object')

# %% [markdown]
# ## I decided to drop off the rg78 and unmod78 because i only want the central 9mer

# %%
df.drop('rg78', axis=1, inplace=True)
df.drop('unmod78', axis=1, inplace=True)
df[:5]
# Out:
#    index      rg69      rg70      rg71      rg72     rg73      rg74      rg75  \
# 0      0  -59.2513  165.8372   83.5081  116.8386  35.0590  149.8438 -153.1143
# 1      1  -51.9629  -78.2528  102.2039   85.5357 -13.3698   97.6019 -131.5027
# 2      2 -115.8034  -31.7155  118.6797   86.4147 -15.5264  -34.9067  -76.6973
# 3      3  138.9181   22.3741  110.6671  101.8984   6.0773  -68.3640 -143.4175
# 4      4  -62.8545  -58.8034   85.0064   91.0527   6.1394  -79.3681 -165.7273
#
#        rg76      rg77   unmod69  unmod70   unmod71   unmod72  unmod73  \
# 0   86.4617  117.8808 -126.2834 -82.6194   78.1411   83.5118  58.0048
# 1   83.8460  107.5770  -84.6551 -57.8616   87.9330   57.3907  58.7422
# 2   64.0712  106.9056  -76.1232 -61.4462   73.7802   58.1371  94.1746
# 3  112.9166   99.0886  -78.4769 -34.3623   70.0909   70.4467  92.4743
# 4  105.1124  124.0989  -99.5704 -93.0268  107.4481  114.8272  44.3946
#
#     unmod74   unmod75   unmod76   unmod77
# 0  179.0481  -98.3822  122.4371   98.4780
# 1  -70.7860 -161.7669  108.7448  102.4572
# 2   -7.5243  -49.2028  111.7993  116.6765
# 3  -49.6539  -28.0702  101.9498   95.7988
# 4  -36.9158  -62.1817  103.8009   82.5470

# %% [markdown]
# # Preview a step far away from the lesion

# %%
fig, ax = plt.subplots()
sns.distplot(df['rg69'],color='blue')
sns.distplot(df['unmod69'],color='orange')
ax.set_xlabel("rg69 and unmod69 chi degrees")

# %% [markdown]
# # Preview the lesion step

# %%
fig, ax = plt.subplots()
#data69=df[['rg69','unmod69']]
sns.distplot(df['rg73'],color='blue',label='rg73')
sns.distplot(df['unmod73'],color='orange',label='unmod73')
plt.legend()
ax.set_xlabel("rg73 and unmod73 gamma degrees")

# %% [markdown]
# # Normalize the range to 0 to 360 degrees

# %%
fig, ax = plt.subplots()
#df['rg73']=df['rg73'].map(lambda x: x+360 if x <0 else x)
#df['unmod73']=df['unmod73'].map(lambda x: x+360 if x <0 else x)
sns.distplot(df['rg73'],color='blue',label='rg73')
sns.distplot(df['unmod73'],color='orange',label='unmod73')
plt.legend()
ax.set_xlabel("rg73 and unmod73 gamma degrees")

# %%
df_73=df[['rg73','unmod73']]
df_73.plot(alpha=0.5)

# %% [markdown]
# # I am going to define a function for this plot so that I can apply to all the 9 plots

# %%
def histplot(step):
    rg='rg'+str(step)
    unmod='unmod'+str(step)
    fig, ax = plt.subplots(figsize=(10,10))
    #df[rg]=df[rg].map(lambda x: x+360 if x <-50 else x)
    #df[unmod]=df[unmod].map(lambda x: x+360 if x <-50 else x)
    sns.distplot(df[rg],color='blue',label=rg)
    sns.distplot(df[unmod],color='orange',label=unmod)
    plt.legend()
    sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2.5})
    ax.set_xlabel(rg +" and " + unmod + " gamma torsion in degrees")
    plt.savefig("./chi_plots/chi_hist_"+str(step)+".png")

# %% [markdown]
# ## let's try it on two steps

# %%
for i in range(69,78):
    print i
    histplot(i)
# Out:
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
