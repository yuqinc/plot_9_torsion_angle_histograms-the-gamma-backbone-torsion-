# %% [markdown]
# # This notebook analyzes the pucker (P) for the rg and unmod for the central 10 steps around the lesion
#
# ## First of all, import usful libraries

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import sys, getopt

from matplotlib import pyplot
from pylab import *
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_color_codes("pastel")
sns.set(style="darkgrid")

# %% [markdown]
# ## Read data, first 10 columns are for rg; second 10 clumns are for unmod

# %%
df=pd.read_csv("./rg10_unmod10_pucker", header=None, delim_whitespace=True).reset_index()

# %%
df[:5]
# Out:
#    index         0         1         2         3        4         5         6  \
# 0      0   75.1768  175.4603  158.1120  157.8189 -81.7442  143.7830  151.9379
# 1      1  116.6530  151.7402  141.7822  136.8996 -82.8100  140.0350  168.2030
# 2      2  117.3829  154.6575  145.8239  153.3610 -81.0977 -178.4987  137.0647
# 3      3   98.3497  148.9371  147.7529  159.8673 -97.0441  179.5154  131.7899
# 4      4   84.1246  148.5323  158.5704  175.4127 -84.5735  163.8817  144.8753
#
#           7         8    ...           10        11        12        13  \
# 0 -149.5228  153.6916    ...     165.4067  130.0438  131.1198 -171.1246
# 1  171.1723  153.3941    ...      49.3975  123.1348  143.7810 -172.9550
# 2  171.3664  139.8421    ...       9.9476  119.8414  137.3649 -178.8621
# 3 -173.3959  141.0786    ...      20.1462  147.6998  146.4671  157.5138
# 4 -143.0695  151.1126    ...     -20.2658  160.3789  144.6842  164.9043
#
#          14        15       16        17        18        19
# 0 -164.3309  152.6581  97.2419 -175.6809  162.2935   83.1084
# 1  163.2716  140.3540  86.3949 -177.1616  148.9794   77.9513
# 2 -166.8332  141.3421  82.5641 -156.5114  147.9170  154.7349
# 3 -179.4263  125.3473  78.3762  165.6079  152.4096  141.2003
# 4  133.5849  133.8841  48.6370  167.1338  153.8144 -158.0819
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (70000, 21)

# %% [markdown]
# ## Create the column names; 10 for rg, 10 for unmod

# %%
list1=["index"]
list2=["rg"+str(x) for x in range(69,79)]
list3=["unmod"+str(x) for x in range(69,79)]
names= list1+list2+list3

# %% [markdown]
# ## Assign column names, and review the dataframe

# %%
df.columns=names
print df.shape
df[:5]
#print df.drop(df.columns[[0]], axis=1, inplace=True)
# Out:
# (70000, 21)
#    index      rg69      rg70      rg71      rg72     rg73      rg74      rg75  \
# 0      0   75.1768  175.4603  158.1120  157.8189 -81.7442  143.7830  151.9379
# 1      1  116.6530  151.7402  141.7822  136.8996 -82.8100  140.0350  168.2030
# 2      2  117.3829  154.6575  145.8239  153.3610 -81.0977 -178.4987  137.0647
# 3      3   98.3497  148.9371  147.7529  159.8673 -97.0441  179.5154  131.7899
# 4      4   84.1246  148.5323  158.5704  175.4127 -84.5735  163.8817  144.8753
#
#        rg76      rg77    ...      unmod69   unmod70   unmod71   unmod72  \
# 0 -149.5228  153.6916    ...     165.4067  130.0438  131.1198 -171.1246
# 1  171.1723  153.3941    ...      49.3975  123.1348  143.7810 -172.9550
# 2  171.3664  139.8421    ...       9.9476  119.8414  137.3649 -178.8621
# 3 -173.3959  141.0786    ...      20.1462  147.6998  146.4671  157.5138
# 4 -143.0695  151.1126    ...     -20.2658  160.3789  144.6842  164.9043
#
#     unmod73   unmod74  unmod75   unmod76   unmod77   unmod78
# 0 -164.3309  152.6581  97.2419 -175.6809  162.2935   83.1084
# 1  163.2716  140.3540  86.3949 -177.1616  148.9794   77.9513
# 2 -166.8332  141.3421  82.5641 -156.5114  147.9170  154.7349
# 3 -179.4263  125.3473  78.3762  165.6079  152.4096  141.2003
# 4  133.5849  133.8841  48.6370  167.1338  153.8144 -158.0819
#
# [5 rows x 21 columns]

# %%
df["rg78"][:5]
# Out:
# 0    157.1066
# 1    150.1247
# 2    142.8033
# 3    142.9385
# 4    129.2832
# Name: rg78, dtype: float64

# %%
print df.columns
# Out:
# Index([u'index', u'rg69', u'rg70', u'rg71', u'rg72', u'rg73', u'rg74', u'rg75',
#        u'rg76', u'rg77', u'rg78', u'unmod69', u'unmod70', u'unmod71',
#        u'unmod72', u'unmod73', u'unmod74', u'unmod75', u'unmod76', u'unmod77',
#        u'unmod78'],
#       dtype='object')

# %% [markdown]
# ## I decided to drop off the rg78 and unmod78 because i only want the central 9mer

# %%
df.drop('rg78', axis=1, inplace=True)
df.drop('unmod78', axis=1, inplace=True)
df[:5]
# Out:
#    index      rg69      rg70      rg71      rg72     rg73      rg74      rg75  \
# 0      0   75.1768  175.4603  158.1120  157.8189 -81.7442  143.7830  151.9379
# 1      1  116.6530  151.7402  141.7822  136.8996 -82.8100  140.0350  168.2030
# 2      2  117.3829  154.6575  145.8239  153.3610 -81.0977 -178.4987  137.0647
# 3      3   98.3497  148.9371  147.7529  159.8673 -97.0441  179.5154  131.7899
# 4      4   84.1246  148.5323  158.5704  175.4127 -84.5735  163.8817  144.8753
#
#        rg76      rg77   unmod69   unmod70   unmod71   unmod72   unmod73  \
# 0 -149.5228  153.6916  165.4067  130.0438  131.1198 -171.1246 -164.3309
# 1  171.1723  153.3941   49.3975  123.1348  143.7810 -172.9550  163.2716
# 2  171.3664  139.8421    9.9476  119.8414  137.3649 -178.8621 -166.8332
# 3 -173.3959  141.0786   20.1462  147.6998  146.4671  157.5138 -179.4263
# 4 -143.0695  151.1126  -20.2658  160.3789  144.6842  164.9043  133.5849
#
#     unmod74  unmod75   unmod76   unmod77
# 0  152.6581  97.2419 -175.6809  162.2935
# 1  140.3540  86.3949 -177.1616  148.9794
# 2  141.3421  82.5641 -156.5114  147.9170
# 3  125.3473  78.3762  165.6079  152.4096
# 4  133.8841  48.6370  167.1338  153.8144

# %% [markdown]
# # Preview a step far away from the lesion

# %%
fig, ax = plt.subplots()
sns.distplot(df['rg69'],bins=100, color='blue')
sns.distplot(df['unmod69'],bins=100,color='orange')
ax.set_xlabel("rg69 and unmod69 Pucker (degrees)")

# %% [markdown]
# # Preview the lesion step

# %%
fig, ax = plt.subplots()
#data69=df[['rg69','unmod69']]
sns.distplot(df['rg73'],bins=100,color='blue',label='rg73')
sns.distplot(df['unmod73'],bins=100, color='orange',label='unmod73')
plt.legend()
ax.set_xlabel("rg73 and unmod73 Pucker (degrees)")

# %% [markdown]
# # Normalize the range to 0 to 360 degrees

# %%
fig, ax = plt.subplots()
df['rg73']=df['rg73'].map(lambda x: x+360 if x <0 else x)
df['unmod73']=df['unmod73'].map(lambda x: x+360 if x <0 else x)
sns.distplot(df['rg73'],color='blue',bins=100,label='rg73')
sns.distplot(df['unmod73'],color='orange',bins=100,label='unmod73')
plt.legend()
ax.set_xlabel("rg73 and unmod73 Pucker (degrees)")

# %%
df['rg73']=df['rg73'].map(lambda x: x+360 if x <0 else x)
df['unmod73']=df['unmod73'].map(lambda x: x+360 if x <0 else x)

df_73=df[['rg73','unmod73']]
df_73.plot(alpha=0.5)

# %% [markdown]
# # I am going to define a function for this plot so that I can apply to all the 9 plots

# %%
def histplot(step):
    rg='rg'+str(step)
    unmod='unmod'+str(step)
    fig, ax = plt.subplots(figsize=(10,10))
    df[rg]=df[rg].map(lambda x: x+360 if x <0 else x)
    df[unmod]=df[unmod].map(lambda x: x+360 if x <0 else x)
    sns.distplot(df[rg],bins=100,color='blue',label=rg)
    sns.distplot(df[unmod],bins=100,color='orange',label=unmod)
    plt.legend()
    
    sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2.5})
    ax.set_xlabel(rg +" and " + unmod + " pucker in degrees")
    plt.savefig("./pucker_plots/pucker_hist_"+str(step)+".png")

# %% [markdown]
# ## let's enumerate all 9 steps

# %%
for i in range(69,78):
    print i
    histplot(i)
# Out:
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
